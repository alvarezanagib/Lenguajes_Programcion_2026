# %% [markdown]
# <a href="https://colab.research.google.com/github/alvarezanagib/Lenguajes_Programcion_2026/blob/main/Trabajo_en_Clase_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Valor Presente neto**

# %% [markdown]
# El **_valor presente neto (VPN)_** es un indicador financiero utilizado para evaluar la rentabilidad de un proceso de inversión.
#
# Este método permite comparar el valor del dinaro hoy frente a valor que tendra en el futuro, considerando una tasa de descuento.
#
# Si es VPN es positivo el proyecto **_genera valor_**, si es negativo el proyecto **_no es financieramente viable_**.

# %% [markdown]
# Los elementos principales del Valor presnete neto son:
#
#
# *   Inversión inicial
# *   Flujos de caja futuros
# *   Tasa de descuento
# *   Horizonte de tiempos

# %% [markdown]
# La formula del Valor presente neto es:
#
# $$ VPN = \sum_{t=1}^{n} \frac{F_t}{(1+r)^t} - I_0 $$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# La información fue consultada en el siguiente enlace:
# >https://economipedia.com/definiciones/valor-presente.html
